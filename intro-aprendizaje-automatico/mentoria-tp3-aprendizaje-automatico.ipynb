# %%
# Definir todos los imports en esta celda
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

import numpy as np
import pandas as pd

# %%
# Especificar la localización del dataset en sus computadoras
dataset_path = "../dataset/reviews_yelp_nn.csv"
ds = pd.read_csv(dataset_path, sep='\t')
# Out:
# /anaconda3/envs/diplodatos/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# ¡Correr solo una vez!
# Descargamos stopwords para crear posteriormente la bag of words.
import nltk

nltk.download('stopwords')

# Verificamos que todo salió bien.
nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /Users/aenet/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Creamos la bag of words usando CountVectorizer. 
# Si se animan como un punto extra, pueden investigar e implementar otra técnica 
# para crear el bag of words.

MIN_NGRAM = 1
MAX_NGRAM = 1
MIN_DF = 5
MAX_DF = 2500

corpus = ds.iloc[:,6].apply(lambda x: np.str_(x))
vectorizer = CountVectorizer(
    ngram_range=(MIN_NGRAM, MAX_NGRAM),
    min_df= MIN_DF,
    max_df= MAX_DF,
    stop_words=stopwords.words('english'))

# Vectorizamos las reviews, la salida es una matriz esparsa densa.
# Esta salida, es la que deben usar como input en sus modelos de ML.
X = vectorizer.fit_transform(corpus)

# %%
# Implementación de modelos
corpus
# Out:
# 0          Best Dim Sum in the city, their cart service i...
# 1          How... HOW did I not head down here sooner? Fo...
# 2          Carnitas were wonderful. First time there and ...
# 3          Great staff who are always willing to help. I ...
# 4          This place is bigger, brighter, new so it's cl...
# 5          Sheer coincidence that I'm writing a review fo...
# 6          just got back from a weekend here......and lov...
# 7          I drive far to get to Lindo Michoacan, but it'...
# 8          Ordered 1 pizza. 3 donairs and cheezy bread at...
# 9          I feel conflicted about reviewing this place. ...
# 10         This is a unique food court option - nothing s...
# 11         Dr Crezee , Beecroft and Stewart are awesome w...
# 12         Came here for breakfast before we headed to Ni...
# 13         What a complete disappointment! I went for lun...
# 14         I questioned what to expect from this store as...
# 15         I was in this store very recently. It's very s...
# 16         AWESOME VIEW! We were also staying at the stra...
# 17         This place does exactly what it sets out to do...
# 18         I fell in love with this place when I went to ...
# 19         It's no longer called Soups and Noodles. It's ...
# 20         Go with the tasting menu. Lobster bisque could...
# 21         Service here is horrible. They didn't page us ...
# 22         This is one of my favorite restaurants to go t...
# 23         Very high end & tasty food. Complements to the...
# 24         Amazing paella! We ordered it when they had th...
# 25         I have to say I've lived across the street for...
# 26         This is probably the last place that anyone wo...
# 27         The spice/heat balance has been improved. The ...
# 28         Worst camera store , bad prices terrible staff...
# 29         Two words:  Ass Juice.  The infamous shot serv...
#                                  ...
# 3342928    First time trying a Poke bowl, and was not dis...
# 3342929    Amazing selection of rolls, love the Big B rol...
# 3342930    Gordon didn't disappoint! We did the prefixed ...
# 3342931    Love this place, they do an amazing job.  I go...
# 3342932    I was pleasantly surprised by how good their f...
# 3342933    The BEST fast food burger on the planet.  Enjo...
# 3342934    Don't go there to sell your records.  Owner of...
# 3342935    The skewers are so tasty!!!! Ramen is average ...
# 3342936    For me, this is 2017. I see nothing wrong with...
# 3342937    This place is a gem for the price.  10oz prime...
# 3342938    Start a lovely weekend brunch out on Willie St...
# 3342939    The food and service is ALWAYS AMAZING! For th...
# 3342940    Best. Place. Ever! I love this place! I'm on t...
# 3342941    I really didn't like the food here. There was ...
# 3342942    I can't wait to return!! Talk about a 5 star, ...
# 3342943    I am someone who is half Italian and this plac...
# 3342944    Just had the WORST customer service experience...
# 3342945    We were looking forward to some bar b que ribs...
# 3342946    The best Indian restaurant in Montreal!!!! I l...
# 3342947    For a party of 3 at peak hours on a Friday nig...
# 3342948    We came to Dragon Boat Fusion for a fam jam di...
# 3342949    My family celebrated our daughters 10th birthd...
# 3342950    When I saw that Matt's had four stars on here,...
# 3342951    Loved this place, lots of comments on the volu...
# 3342952    I went with a guest and we ordered filet migno...
# 3342953    Slow service to seat and then to serve. Left w...
# 3342954    I stayed at the Bellagio for 3 nights this mon...
# 3342955    1: book an appointment!  You get to walk past ...
# 3342956    This review is based on quality of pricing, no...
# 3342957    I posted and review earlier that was removed. ...
# Name: text, Length: 3342958, dtype: object

# %%
# Calculo de las métricas de los modelos implementados.
